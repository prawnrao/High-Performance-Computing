# %%
# !conda install -c conda-forge -y fenics
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.4.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/nbuser/anaconda3_501
#
#   added / updated specs:
#     - fenics
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.13.3               |py36_blas_openblas_201         8.7 MB  conda-forge
#     ply-3.10                   |           py36_0          78 KB  conda-forge
#     petsc-3.8.3                |  blas_openblas_1         7.6 MB  conda-forge
#     mpich-3.2.1                |                0         5.3 MB  conda-forge
#     wheel-0.30.0               |           py36_2          66 KB  conda-forge
#     pip-9.0.1                  |           py36_1         1.7 MB  conda-forge
# ...

# %%
from dolfin import *
